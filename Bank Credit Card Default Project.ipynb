# %% [markdown]
# # Bank Credit Risk Project

# %% [markdown]
# ### Importing Basic Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Importing txt Data File

# %%
df=pd.read_csv("XYZCorp_LendingData.txt", sep="\t")
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\805807727.py:1: DtypeWarning: Columns (17,45,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("XYZCorp_LendingData.txt", sep="\t")

# %% [markdown]
# ### Checking the shape and names of columns and info about the datatset

# %%
df.shape
# Out:
# (855969, 73)

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'open_acc_6m', 'open_il_6m', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'default_ind'],
#       dtype='object')

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... il_util open_rv_12m open_rv_24m  \
# 0     10.65       162.87     B        B2  ...     NaN         NaN         NaN
# 1     15.27        59.83     C        C4  ...     NaN         NaN         NaN
# 2     15.96        84.33     C        C5  ...     NaN         NaN         NaN
# 3     13.49       339.31     C        C1  ...     NaN         NaN         NaN
# 4     12.69        67.79     B        B5  ...     NaN         NaN         NaN
#
#    max_bal_bc all_util total_rev_hi_lim inq_fi total_cu_tl inq_last_12m  \
# 0         NaN      NaN              NaN    NaN         NaN          NaN
# 1         NaN      NaN              NaN    NaN         NaN          NaN
# 2         NaN      NaN              NaN    NaN         NaN          NaN
# 3         NaN      NaN              NaN    NaN         NaN          NaN
# 4         NaN      NaN              NaN    NaN         NaN          NaN
#
#   default_ind
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
#
# [5 rows x 73 columns]

# %% [markdown]
# ### Here as we can see some of the columns are not significant as they don't have any singnificance on dependant variable

# %%
df.drop(["id","member_id","zip_code","addr_state","policy_code","title","pymnt_plan",
         "application_type","emp_title","emp_length","collections_12_mths_ex_med",
         "total_rec_late_fee","recoveries","collection_recovery_fee","acc_now_delinq"],axis=1,inplace=True)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Remove NA's

# %%
# Variables having NA's
def get_na(data): 
    null_vars = data.isnull().sum()
    null_vars = null_vars[null_vars > 0]
    if(len(null_vars) > 0):
        null_vars.sort_values(inplace=True)
        return null_vars
    else:
        print("No column have NA values")
get_na(df)
# Out:
# last_credit_pull_d                 50
# revol_util                        446
# last_pymnt_d                     8862
# tot_coll_amt                    67313
# tot_cur_bal                     67313
# total_rev_hi_lim                67313
# next_pymnt_d                   252971
# mths_since_last_delinq         439812
# mths_since_last_major_derog    642830
# mths_since_last_record         724785
# desc                           734159
# open_acc_6m                    842681
# open_il_12m                    842681
# open_rv_24m                    842681
# open_il_24m                    842681
# open_il_6m                     842681
# total_cu_tl                    842681
# inq_last_12m                   842681
# inq_fi                         842681
# total_bal_il                   842681
# max_bal_bc                     842681
# all_util                       842681
# open_rv_12m                    842681
# mths_since_rcnt_il             843035
# il_util                        844360
# annual_inc_joint               855527
# verification_status_joint      855527
# dti_joint                      855529
# dtype: int64

# %% [markdown]
# ### Drop columns with more than 90% NA's

# %%
df.drop(["dti_joint","annual_inc_joint","verification_status_joint","il_util","mths_since_rcnt_il","inq_last_12m","total_cu_tl",
          "open_acc_6m","open_il_6m","open_il_12m","open_il_24m","total_bal_il","open_rv_12m","open_rv_24m","max_bal_bc","all_util",
          "inq_fi","desc"],axis=1,inplace=True)

# %%
get_na(df)
# Out:
# last_credit_pull_d                 50
# revol_util                        446
# last_pymnt_d                     8862
# tot_coll_amt                    67313
# total_rev_hi_lim                67313
# tot_cur_bal                     67313
# next_pymnt_d                   252971
# mths_since_last_delinq         439812
# mths_since_last_major_derog    642830
# mths_since_last_record         724785
# dtype: int64

# %% [markdown]
# ### Fill NA's in numerical and categorical columns by mean and mode respectively

# %%
df['last_credit_pull_d']=df['last_credit_pull_d'].fillna(df["last_credit_pull_d"].mode()[0])
df['last_pymnt_d']=df['last_pymnt_d'].fillna(df["last_pymnt_d"].mode()[0])
df['next_pymnt_d']=df['next_pymnt_d'].fillna(df["next_pymnt_d"].mode()[0])
df['mths_since_last_delinq']=df['mths_since_last_delinq'].fillna(df["mths_since_last_delinq"].mode()[0])
df['mths_since_last_major_derog']=df['mths_since_last_major_derog'].fillna(df["mths_since_last_major_derog"].mode()[0])
df['mths_since_last_record']=df['mths_since_last_record'].fillna(df["mths_since_last_record"].mode()[0])

# %%
df['revol_util']=df['revol_util'].fillna(df["revol_util"].mean())
df['tot_coll_amt']=df['tot_coll_amt'].fillna(df["tot_coll_amt"].mean())
df['tot_cur_bal']=df['tot_cur_bal'].fillna(df["tot_cur_bal"].mean())
df['total_rev_hi_lim']=df['total_rev_hi_lim'].fillna(df["total_rev_hi_lim"].mean())

# %%
get_na(df)
# Out:
# No column have NA values

# %% [markdown]
# ### Change dates to date type and extract month and year

# %%
df["earliest_cr_line"]=pd.to_datetime(df["earliest_cr_line"])
df["last_pymnt_d"]=pd.to_datetime(df["last_pymnt_d"])
df["next_pymnt_d"]=pd.to_datetime(df["next_pymnt_d"])
df["last_credit_pull_d"]=pd.to_datetime(df["last_credit_pull_d"])
df["issue_d"]=pd.to_datetime(df["issue_d"])
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\1836837618.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["earliest_cr_line"]=pd.to_datetime(df["earliest_cr_line"])
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\1836837618.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["last_pymnt_d"]=pd.to_datetime(df["last_pymnt_d"])
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\1836837618.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["next_pymnt_d"]=pd.to_datetime(df["next_pymnt_d"])
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\1836837618.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["last_credit_pull_d"]=pd.to_datetime(df["last_credit_pull_d"])
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\1836837618.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["issue_d"]=pd.to_datetime(df["issue_d"])

# %%
df.next_pymnt_d.value_counts()
# Out:
# next_pymnt_d
# 2016-02-01    787065
# 2016-01-01     68838
# 2016-03-01        66
# Name: count, dtype: int64

# %%
df.drop(["next_pymnt_d"], axis=1, inplace=True)

# %%
df["earliest_cr_line_month"] = df['earliest_cr_line'].map(lambda x: x.month)
df["earliest_cr_line_year"] = df['earliest_cr_line'].map(lambda x: x.year)

# %%
df["last_pymnt_d_month"] = df['last_pymnt_d'].map(lambda x: x.month)
df["last_pymnt_d_year"] = df['last_pymnt_d'].map(lambda x: x.year)

# %%
df["last_credit_pull_d_month"] = df['last_credit_pull_d'].map(lambda x: x.month)
df["last_credit_pull_d_year"] = df['last_credit_pull_d'].map(lambda x: x.year)

# %%
df.drop(["earliest_cr_line","last_pymnt_d","last_credit_pull_d"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0     5000.0       5000.0           4975.0   36 months     10.65       162.87
# 1     2500.0       2500.0           2500.0   60 months     15.27        59.83
# 2     2400.0       2400.0           2400.0   36 months     15.96        84.33
# 3    10000.0      10000.0          10000.0   36 months     13.49       339.31
# 4     3000.0       3000.0           3000.0   60 months     12.69        67.79
#
#   grade sub_grade home_ownership  annual_inc  ... tot_coll_amt    tot_cur_bal  \
# 0     B        B2           RENT     24000.0  ...   225.412882  139766.247529
# 1     C        C4           RENT     30000.0  ...   225.412882  139766.247529
# 2     C        C5           RENT     12252.0  ...   225.412882  139766.247529
# 3     C        C1           RENT     49200.0  ...   225.412882  139766.247529
# 4     B        B5           RENT     80000.0  ...   225.412882  139766.247529
#
#   total_rev_hi_lim  default_ind  earliest_cr_line_month  \
# 0     32163.574526            0                       1
# 1     32163.574526            1                       4
# 2     32163.574526            0                      11
# 3     32163.574526            0                       2
# 4     32163.574526            0                       1
#
#    earliest_cr_line_year  last_pymnt_d_month  last_pymnt_d_year  \
# 0                   1985                   1               2015
# 1                   1999                   4               2013
# 2                   2001                   6               2014
# 3                   1996                   1               2015
# 4                   1996                   1               2016
#
#    last_credit_pull_d_month  last_credit_pull_d_year
# 0                         1                     2016
# 1                         9                     2013
# 2                         1                     2016
# 3                         1                     2015
# 4                         1                     2016
#
# [5 rows x 42 columns]

# %% [markdown]
# # EDA
# ### CATEGORICAL ATTRIBUTES

# %%
sns.countplot(df["term"])
# Out:
# <Axes: xlabel='count', ylabel='term'>

# %%
sns.countplot(df["grade"])
# Out:
# <Axes: xlabel='count', ylabel='grade'>

# %%
sns.countplot(df["sub_grade"])
# Out:
# <Axes: xlabel='count', ylabel='sub_grade'>

# %%
sns.countplot(df["home_ownership"])
# Out:
# <Axes: xlabel='count', ylabel='home_ownership'>

# %%
sns.countplot(df["verification_status"])
# Out:
# <Axes: xlabel='count', ylabel='verification_status'>

# %%
sns.countplot(df["purpose"])
# Out:
# <Axes: xlabel='count', ylabel='purpose'>

# %%
sns.countplot(df["initial_list_status"])
# Out:
# <Axes: xlabel='count', ylabel='initial_list_status'>

# %% [markdown]
# # Numerical Attributes

# %%
sns.distplot(df["loan_amnt"])
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\3720033395.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["loan_amnt"])
# <Axes: xlabel='loan_amnt', ylabel='Density'>

# %%
sns.distplot(df["funded_amnt"])
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\2162443209.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["funded_amnt"])
# <Axes: xlabel='funded_amnt', ylabel='Density'>

# %%
fig,ax=plt.subplots(1,2,figsize=(16,5))
# Making a plot with 2 subplots
loan_amount=df["loan_amnt"].values
funded_amount=df["funded_amnt"].values
sns.distplot(loan_amount,ax=ax[0],color='#000000')
ax[0].set_title("Loan apllied by the Borrower", fontsize=14)
sns.distplot(funded_amount,ax=ax[1])
ax[1].set_title("Amount Funded by the Borrower", fontsize=14)
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\3464054989.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(loan_amount,ax=ax[0],color='#000000')
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\3464054989.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(funded_amount,ax=ax[1])
# Text(0.5, 1.0, 'Amount Funded by the Borrower')

# %%
sns.distplot(df["funded_amnt_inv"])
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\2520594829.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["funded_amnt_inv"])
# <Axes: xlabel='funded_amnt_inv', ylabel='Density'>

# %%
sns.distplot(df["int_rate"])
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\576339031.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["int_rate"])
# <Axes: xlabel='int_rate', ylabel='Density'>

# %%
sns.distplot(df["installment"])
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\3206694565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["installment"])
# <Axes: xlabel='installment', ylabel='Density'>

# %%
sns.distplot(df["annual_inc"])
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\3761385195.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["annual_inc"])
# <Axes: xlabel='annual_inc', ylabel='Density'>

# %% [markdown]
# ### Upper Caping and Lower Caping for numerical Feature

# %%
def set_caping(column, capping):
   
    mean = df[column].mean() # Mean of the column
    std = df[column].std() # Standard Deviation of the column
   
    UCL = mean + (3 * std)
    LCL = mean - (3 * std)
    if capping == "both":
        df[column] = np.where((df[column] > UCL), UCL , df[column])
        df[column] = np.where((df[column] < UCL), LCL , df[column])
       
    elif capping == "upper":
        df[column] = np.where((df[column] > UCL), UCL , df[column])
       
    elif capping == "lower":
        df[column] = np.where((df[column] < UCL), LCL ,df[column])
    else:
        print("Please enter proper value of capping parameter. \n Possible values:\tboth\tupper\tlower")

# %%
set_caping("annual_inc",capping="upper")
sns.distplot(df["annual_inc"])
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\3794050220.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["annual_inc"])
# <Axes: xlabel='annual_inc', ylabel='Density'>

# %%
sns.distplot(df["dti"])
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\2299896116.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["dti"])
# <Axes: xlabel='dti', ylabel='Density'>

# %%
set_caping("dti",capping="upper")
sns.distplot(df["dti"])
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\1428354020.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["dti"])
# <Axes: xlabel='dti', ylabel='Density'>

# %%
set_caping("delinq_2yrs",capping="upper")
plt.hist(df["delinq_2yrs"])
plt.show()

# %%
plt.hist(df["inq_last_6mths"])
plt.show()

# %%
set_caping("inq_last_6mths",capping="upper")
plt.hist(df["inq_last_6mths"])
plt.show()

# %%
plt.hist(df["mths_since_last_delinq"])
plt.show()

# %%
set_caping("mths_since_last_delinq",capping="upper")
plt.hist(df["mths_since_last_delinq"])
plt.show()

# %%
plt.hist(df["mths_since_last_record"])
plt.show()

# %%
plt.hist(df["open_acc"])
plt.show()

# %%
set_caping("open_acc",capping="upper")
plt.hist(df["open_acc"])
plt.show()

# %%
plt.hist(df["pub_rec"])
plt.show()

# %%
set_caping("pub_rec",capping="upper")
plt.hist(df["pub_rec"])
plt.show()

# %%
plt.hist(df["revol_bal"])
plt.show()

# %%
set_caping("revol_bal",capping="upper")
plt.hist(df["revol_bal"])
plt.show()

# %%
plt.hist(df["revol_util"])
plt.show()

# %%
set_caping("revol_util",capping="upper")
plt.hist(df["revol_util"])
plt.show()

# %%
plt.hist(df["total_acc"])
plt.show()

# %%
set_caping("total_acc",capping="upper")
plt.hist(df["total_acc"])
plt.show()

# %%
plt.hist(df["out_prncp"])
plt.show()

# %%
set_caping("out_prncp",capping="upper")
plt.hist(df["out_prncp"])
plt.show()

# %%
plt.hist(df["out_prncp_inv"])
plt.show()

# %%
set_caping("out_prncp_inv",capping="upper")
plt.hist(df["out_prncp_inv"])
plt.show()

# %%
plt.hist(df["total_pymnt"])
plt.show()

# %%
set_caping("total_pymnt",capping="upper")
plt.hist(df["total_pymnt"])
plt.show()

# %%
plt.hist(df["total_pymnt_inv"])
plt.show()

# %%
set_caping("total_pymnt_inv",capping="upper")
plt.hist(df["total_pymnt_inv"])
plt.show()

# %%
plt.hist(df["total_rec_prncp"])
plt.show()

# %%
plt.hist(df["total_rec_int"])
plt.show()

# %%
set_caping("total_rec_int",capping="upper")
plt.hist(df["total_rec_int"])
plt.show()

# %%
plt.hist(df["last_pymnt_amnt"])
plt.show()

# %%
set_caping("last_pymnt_amnt",capping="upper")
plt.hist(df["last_pymnt_amnt"])
plt.show()

# %%
plt.hist(df["mths_since_last_major_derog"])
plt.show()

# %%
set_caping("mths_since_last_major_derog",capping="upper")
plt.hist(df["mths_since_last_major_derog"])
plt.show()

# %%
plt.hist(df["tot_coll_amt"])
plt.show()

# %%
# Upper Caping and Lower Caping for numerical Feature

def set_caping_1(column, capping):
   
    mean = df[column].mean() # Mean of the column
    std = df[column].std() # Standard Deviation of the column
   
    UCL = mean + (0.5 * std)
    LCL = mean - (0.5 * std)
    if capping == "both":
        df[column] = np.where((df[column] > UCL), UCL , df[column])
        df[column] = np.where((df[column] < UCL), LCL , df[column])
       
    elif capping == "upper":
        df[column] = np.where((df[column] > UCL), UCL , df[column])
       
    elif capping == "lower":
        df[column] = np.where((df[column] < UCL), LCL ,df[column])
    else:
        print("Please enter proper value of capping parameter. \n Possible values:\tboth\tupper\tlower")

# %%
set_caping_1("tot_coll_amt",capping="upper")
plt.hist(df["tot_coll_amt"])
plt.show()

# %%
plt.hist(df["tot_cur_bal"])
plt.show()

# %%
set_caping("tot_cur_bal",capping="upper")
plt.hist(df["tot_cur_bal"])
plt.show()

# %%
plt.hist(df["total_rev_hi_lim"])
plt.show()

# %%
set_caping("total_rev_hi_lim",capping="upper")
plt.hist(df["total_rev_hi_lim"])
plt.show()

# %% [markdown]
# # Corelation Matrix

# %%
corr=df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, annot=True,cmap="BuPu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 corr=df.corr()
#       2 plt.figure(figsize=(20,20))
#       3 sns.heatmap(corr, annot=True,cmap="BuPu")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: ' 36 months'

# %%
#Check vif

# %%
dat=df[["loan_amnt","funded_amnt","funded_amnt_inv","installment","out_prncp_inv","out_prncp",
         "total_pymnt_inv","total_pymnt","total_rec_prncp"]]

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\vs\appdata\local\programs\python\python313\lib\site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\vs\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (2.3.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\vs\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (1.16.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\vs\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (2.3.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\vs\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\vs\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vs\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vs\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vs\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vs\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
vif_data = pd.DataFrame() 
vif_data["feature"] = dat.columns

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(dat.values, i) 
                          for i in range(len(dat.columns))] 
  
print(vif_data)
# Out:
#            feature            VIF
# 0        loan_amnt    2791.272595
# 1      funded_amnt   11613.931683
# 2  funded_amnt_inv    8709.867638
# 3      installment      42.432177
# 4    out_prncp_inv  375804.496819
# 5        out_prncp  375779.173087
# 6  total_pymnt_inv    3338.644282
# 7      total_pymnt    3380.589661
# 8  total_rec_prncp      30.354579

# %% [markdown]
# ### Drop highly correlated variables

# %%
df.drop(["funded_amnt","funded_amnt_inv","out_prncp_inv",
         "total_pymnt"],axis=1,inplace=True)

# %% [markdown]
# ### Dummification of Categorical variables

# %%
cat_data = df.select_dtypes('O')
cat_data.columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'purpose', 'initial_list_status'],
#       dtype='object')

# %%
df=pd.get_dummies(data=df,columns=['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status',
       'purpose', 'initial_list_status'],drop_first=True)

# %%
df
# Out:
#         loan_amnt  int_rate  installment  annual_inc    issue_d    dti  \
# 0          5000.0     10.65       162.87     24000.0 2011-12-01  27.65
# 1          2500.0     15.27        59.83     30000.0 2011-12-01   1.00
# 2          2400.0     15.96        84.33     12252.0 2011-12-01   8.72
# 3         10000.0     13.49       339.31     49200.0 2011-12-01  20.00
# 4          3000.0     12.69        67.79     80000.0 2011-12-01  17.94
# ...           ...       ...          ...         ...        ...    ...
# 855964    10000.0     11.99       332.10     31000.0 2015-01-01  28.69
# 855965    24000.0     11.99       797.03     79000.0 2015-01-01   3.90
# 855966    13000.0     15.99       316.07     35000.0 2015-01-01  30.90
# 855967    12000.0     19.99       317.86     64400.0 2015-01-01  27.19
# 855968    20000.0     11.99       664.20    100000.0 2015-01-01  10.83
#
#         delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# 0               0.0        1.000000                     9.0
# 1               0.0        3.573014                     9.0
# 2               0.0        2.000000                     9.0
# 3               0.0        1.000000                    35.0
# 4               0.0        0.000000                    38.0
# ...             ...             ...                     ...
# 855964          0.0        0.000000                     9.0
# 855965          0.0        1.000000                    26.0
# 855966          0.0        0.000000                     9.0
# 855967          1.0        2.000000                    22.0
# 855968          0.0        1.000000                     9.0
#
#         mths_since_last_record  ...  purpose_house  purpose_major_purchase  \
# 0                         61.0  ...          False                   False
# 1                         61.0  ...          False                   False
# 2                         61.0  ...          False                   False
# 3                         61.0  ...          False                   False
# 4                         61.0  ...          False                   False
# ...                        ...  ...            ...                     ...
# 855964                    77.0  ...          False                   False
# 855965                    61.0  ...          False                   False
# 855966                    84.0  ...          False                   False
# 855967                    61.0  ...          False                   False
# 855968                   110.0  ...          False                   False
#
#         purpose_medical  purpose_moving  purpose_other  \
# 0                 False           False          False
# 1                 False           False          False
# 2                 False           False          False
# 3                 False           False           True
# 4                 False           False           True
# ...                 ...             ...            ...
# 855964            False           False          False
# 855965            False           False          False
# 855966            False           False          False
# 855967            False           False          False
# 855968            False           False          False
#
#         purpose_renewable_energy  purpose_small_business  purpose_vacation  \
# 0                          False                   False             False
# 1                          False                   False             False
# 2                          False                    True             False
# 3                          False                   False             False
# 4                          False                   False             False
# ...                          ...                     ...               ...
# 855964                     False                   False             False
# 855965                     False                   False             False
# 855966                     False                   False             False
# 855967                     False                   False             False
# 855968                     False                   False             False
#
#         purpose_wedding  initial_list_status_w
# 0                 False                  False
# 1                 False                  False
# 2                 False                  False
# 3                 False                  False
# 4                 False                  False
# ...                 ...                    ...
# 855964            False                  False
# 855965            False                  False
# 855966            False                   True
# 855967            False                   True
# 855968            False                  False
#
# [855969 rows x 93 columns]

# %%
df.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    issue_d    dti  \
# 0     5000.0     10.65       162.87     24000.0 2011-12-01  27.65
# 1     2500.0     15.27        59.83     30000.0 2011-12-01   1.00
# 2     2400.0     15.96        84.33     12252.0 2011-12-01   8.72
# 3    10000.0     13.49       339.31     49200.0 2011-12-01  20.00
# 4     3000.0     12.69        67.79     80000.0 2011-12-01  17.94
#
#    delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# 0          0.0        1.000000                     9.0
# 1          0.0        3.573014                     9.0
# 2          0.0        2.000000                     9.0
# 3          0.0        1.000000                    35.0
# 4          0.0        0.000000                    38.0
#
#    mths_since_last_record  ...  purpose_house  purpose_major_purchase  \
# 0                    61.0  ...          False                   False
# 1                    61.0  ...          False                   False
# 2                    61.0  ...          False                   False
# 3                    61.0  ...          False                   False
# 4                    61.0  ...          False                   False
#
#    purpose_medical  purpose_moving  purpose_other  purpose_renewable_energy  \
# 0            False           False          False                     False
# 1            False           False          False                     False
# 2            False           False          False                     False
# 3            False           False           True                     False
# 4            False           False           True                     False
#
#    purpose_small_business  purpose_vacation  purpose_wedding  \
# 0                   False             False            False
# 1                   False             False            False
# 2                    True             False            False
# 3                   False             False            False
# 4                   False             False            False
#
#    initial_list_status_w
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
#
# [5 rows x 93 columns]

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# ### Sort the data on the basis of 'issue_d' date

# %%
df = df.sort_values("issue_d")

# %%
df.head()
# Out:
#        loan_amnt  int_rate  installment  annual_inc    issue_d    dti  \
# 39693     7500.0     13.75       255.43     22000.0 2007-06-01  14.29
# 39671     5000.0      7.43       155.38    150000.0 2007-07-01   0.00
# 39659     5750.0      7.43       178.69    125000.0 2007-07-01   0.27
# 39660     5000.0      7.43       155.38     40000.0 2007-07-01   2.55
# 39666     1200.0     11.54        39.60     20000.0 2007-07-01   2.04
#
#        delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# 39693          1.0             0.0                    11.0
# 39671          0.0             0.0                     0.0
# 39659          0.0             0.0                     0.0
# 39660          0.0             2.0                     0.0
# 39666          0.0             2.0                    24.0
#
#        mths_since_last_record  ...  purpose_house  purpose_major_purchase  \
# 39693                     0.0  ...          False                   False
# 39671                     0.0  ...          False                   False
# 39659                     0.0  ...          False                   False
# 39660                     0.0  ...          False                   False
# 39666                     0.0  ...          False                   False
#
#        purpose_medical  purpose_moving  purpose_other  \
# 39693            False           False          False
# 39671            False           False          False
# 39659            False           False          False
# 39660            False           False          False
# 39666            False           False          False
#
#        purpose_renewable_energy  purpose_small_business  purpose_vacation  \
# 39693                     False                   False             False
# 39671                     False                   False             False
# 39659                     False                   False             False
# 39660                     False                   False             False
# 39666                     False                   False             False
#
#        purpose_wedding  initial_list_status_w
# 39693            False                  False
# 39671            False                  False
# 39659            False                  False
# 39660            False                  False
# 39666            False                  False
#
# [5 rows x 93 columns]

# %%
print("Initial Date:",df["issue_d"].min())
print("End Date:",df["issue_d"].max())
# Out:
# Initial Date: 2007-06-01 00:00:00
# End Date: 2015-12-01 00:00:00

# %%
df["loan_status"]=df["default_ind"]

# %%
df.drop(["default_ind"],axis=1, inplace=True)

# %%
df.reset_index().head()
# Out:
#    index  loan_amnt  int_rate  installment  annual_inc    issue_d    dti  \
# 0  39693     7500.0     13.75       255.43     22000.0 2007-06-01  14.29
# 1  39671     5000.0      7.43       155.38    150000.0 2007-07-01   0.00
# 2  39659     5750.0      7.43       178.69    125000.0 2007-07-01   0.27
# 3  39660     5000.0      7.43       155.38     40000.0 2007-07-01   2.55
# 4  39666     1200.0     11.54        39.60     20000.0 2007-07-01   2.04
#
#    delinq_2yrs  inq_last_6mths  mths_since_last_delinq  ...  \
# 0          1.0             0.0                    11.0  ...
# 1          0.0             0.0                     0.0  ...
# 2          0.0             0.0                     0.0  ...
# 3          0.0             2.0                     0.0  ...
# 4          0.0             2.0                    24.0  ...
#
#    purpose_major_purchase  purpose_medical  purpose_moving  purpose_other  \
# 0                   False            False           False          False
# 1                   False            False           False          False
# 2                   False            False           False          False
# 3                   False            False           False          False
# 4                   False            False           False          False
#
#    purpose_renewable_energy  purpose_small_business  purpose_vacation  \
# 0                     False                   False             False
# 1                     False                   False             False
# 2                     False                   False             False
# 3                     False                   False             False
# 4                     False                   False             False
#
#    purpose_wedding  initial_list_status_w  loan_status
# 0            False                  False            0
# 1            False                  False            0
# 2            False                  False            0
# 3            False                  False            0
# 4            False                  False            0
#
# [5 rows x 94 columns]

# %% [markdown]
# # Standardize the variables

# %% [markdown]
# ### Standardize the variables by removing the issue_d column as it contains the date

# %%
x=df.iloc[::,0:90]

# %%
x.drop(["issue_d"], axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_scaled_df= pd.DataFrame(x_scaled, index=x.index, columns=x.columns)

# %%
x_scaled_df
# Out:
#         loan_amnt  int_rate  installment  annual_inc       dti  delinq_2yrs  \
# 39693   -0.859974  0.127663    -0.741848   -1.238252 -0.458950     1.117117
# 39671   -1.156698 -1.319103    -1.152348    1.822286 -2.181956    -0.429449
# 39659   -1.067681 -1.319103    -1.056708    1.224525 -2.149401    -0.429449
# 39660   -1.156698 -1.319103    -1.152348   -0.807864 -1.874492    -0.429449
# 39666   -1.607719 -0.378247    -1.627388   -1.286073 -1.935985    -0.429449
# ...           ...       ...          ...         ...       ...          ...
# 475960  -0.041016 -0.275233     0.172250   -0.401386  0.488764    -0.429449
# 475959   0.623646 -1.802121     0.681345    0.602853 -0.661515    -0.429449
# 475958  -0.325871  0.109350    -0.652608   -0.807864  1.471444    -0.429449
# 475964   2.403991 -0.451501     2.926523    1.104972 -1.841937    -0.429449
# 486158   2.344646  0.507669     1.608202    0.052913  0.943329    -0.429449
#
#         inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 39693        -0.730736               -0.518281               -5.471015
# 39671        -0.730736               -1.076572               -5.471015
# 39659        -0.730736               -1.076572               -5.471015
# 39660         1.458369               -1.076572               -5.471015
# 39666         1.458369                0.141517               -5.471015
# ...                ...                     ...                     ...
# 475960       -0.730736               -0.619789               -0.127066
# 475959       -0.730736               -0.619789               -0.127066
# 475958        0.363817               -0.619789               -0.127066
# 475964       -0.730736                1.055084               -0.127066
# 486158       -0.730736               -0.619789               -0.127066
#
#         open_acc  ...  purpose_educational  purpose_home_improvement  \
# 39693  -0.881723  ...            -0.019519                 -0.248956
# 39671  -1.864116  ...            -0.019519                  4.016772
# 39659  -0.292287  ...            -0.019519                 -0.248956
# 39660  -1.471159  ...            -0.019519                 -0.248956
# 39666  -1.667638  ...            -0.019519                 -0.248956
# ...          ...  ...                  ...                       ...
# 475960 -0.488766  ...            -0.019519                 -0.248956
# 475959 -0.095809  ...            -0.019519                 -0.248956
# 475958 -0.292287  ...            -0.019519                 -0.248956
# 475964 -0.095809  ...            -0.019519                  4.016772
# 486158  1.279541  ...            -0.019519                 -0.248956
#
#         purpose_house  purpose_major_purchase  purpose_medical  \
# 39693       -0.064195               -0.140574        -0.098306
# 39671       -0.064195               -0.140574        -0.098306
# 39659       -0.064195               -0.140574        -0.098306
# 39660       -0.064195               -0.140574        -0.098306
# 39666       -0.064195               -0.140574        -0.098306
# ...               ...                     ...              ...
# 475960      -0.064195               -0.140574        -0.098306
# 475959      -0.064195               -0.140574        -0.098306
# 475958      -0.064195               -0.140574        -0.098306
# 475964      -0.064195               -0.140574        -0.098306
# 486158      -0.064195               -0.140574        -0.098306
#
#         purpose_moving  purpose_other  purpose_renewable_energy  \
# 39693        -0.077877      -0.224149                 -0.025334
# 39671        -0.077877      -0.224149                 -0.025334
# 39659        -0.077877      -0.224149                 -0.025334
# 39660        -0.077877      -0.224149                 -0.025334
# 39666        -0.077877      -0.224149                 -0.025334
# ...                ...            ...                       ...
# 475960       -0.077877      -0.224149                 -0.025334
# 475959       -0.077877      -0.224149                 -0.025334
# 475958       -0.077877      -0.224149                 -0.025334
# 475964       -0.077877      -0.224149                 -0.025334
# 486158       -0.077877      -0.224149                 -0.025334
#
#         purpose_small_business  purpose_vacation
# 39693                -0.107535         -0.073038
# 39671                -0.107535         -0.073038
# 39659                -0.107535         -0.073038
# 39660                -0.107535         -0.073038
# 39666                -0.107535         -0.073038
# ...                        ...               ...
# 475960               -0.107535         -0.073038
# 475959               -0.107535         -0.073038
# 475958               -0.107535         -0.073038
# 475964               -0.107535         -0.073038
# 486158               -0.107535         -0.073038
#
# [855969 rows x 89 columns]

# %%
x_join=x_scaled_df.join(df["loan_status"])

# %%
x_final=x_join.join(df["issue_d"])

# %%
x_final.head()
# Out:
#        loan_amnt  int_rate  installment  annual_inc       dti  delinq_2yrs  \
# 39693  -0.859974  0.127663    -0.741848   -1.238252 -0.458950     1.117117
# 39671  -1.156698 -1.319103    -1.152348    1.822286 -2.181956    -0.429449
# 39659  -1.067681 -1.319103    -1.056708    1.224525 -2.149401    -0.429449
# 39660  -1.156698 -1.319103    -1.152348   -0.807864 -1.874492    -0.429449
# 39666  -1.607719 -0.378247    -1.627388   -1.286073 -1.935985    -0.429449
#
#        inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 39693       -0.730736               -0.518281               -5.471015
# 39671       -0.730736               -1.076572               -5.471015
# 39659       -0.730736               -1.076572               -5.471015
# 39660        1.458369               -1.076572               -5.471015
# 39666        1.458369                0.141517               -5.471015
#
#        open_acc  ...  purpose_house  purpose_major_purchase  purpose_medical  \
# 39693 -0.881723  ...      -0.064195               -0.140574        -0.098306
# 39671 -1.864116  ...      -0.064195               -0.140574        -0.098306
# 39659 -0.292287  ...      -0.064195               -0.140574        -0.098306
# 39660 -1.471159  ...      -0.064195               -0.140574        -0.098306
# 39666 -1.667638  ...      -0.064195               -0.140574        -0.098306
#
#        purpose_moving  purpose_other  purpose_renewable_energy  \
# 39693       -0.077877      -0.224149                 -0.025334
# 39671       -0.077877      -0.224149                 -0.025334
# 39659       -0.077877      -0.224149                 -0.025334
# 39660       -0.077877      -0.224149                 -0.025334
# 39666       -0.077877      -0.224149                 -0.025334
#
#        purpose_small_business  purpose_vacation  loan_status    issue_d
# 39693               -0.107535         -0.073038            0 2007-06-01
# 39671               -0.107535         -0.073038            0 2007-07-01
# 39659               -0.107535         -0.073038            0 2007-07-01
# 39660               -0.107535         -0.073038            0 2007-07-01
# 39666               -0.107535         -0.073038            0 2007-07-01
#
# [5 rows x 91 columns]

# %% [markdown]
# ### Divide the dataset into Train and test data on the basis of issue_d
# #### Training data is from 2007 till May 2015
# #### Testing data is from Jun 2015 till Dec 2015

# %%
train=x_final[x_final["issue_d"]<"2015-06-01"]
test=x_final[x_final["issue_d"]>="2015-06-01"]

# %%
train.drop(["issue_d"], axis=1,inplace=True)
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\3674458782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.drop(["issue_d"], axis=1,inplace=True)

# %%
test.drop(["issue_d"], axis=1,inplace=True)
# Out:
# C:\Users\vs\AppData\Local\Temp\ipykernel_7296\4090130254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop(["issue_d"], axis=1,inplace=True)

# %%
train.loan_status.value_counts()
# Out:
# loan_status
# 0    552822
# 1     46156
# Name: count, dtype: int64

# %%
test.loan_status.value_counts()
# Out:
# loan_status
# 0    256680
# 1       311
# Name: count, dtype: int64

# %%
train.head()
# Out:
#        loan_amnt  int_rate  installment  annual_inc       dti  delinq_2yrs  \
# 39693  -0.859974  0.127663    -0.741848   -1.238252 -0.458950     1.117117
# 39671  -1.156698 -1.319103    -1.152348    1.822286 -2.181956    -0.429449
# 39659  -1.067681 -1.319103    -1.056708    1.224525 -2.149401    -0.429449
# 39660  -1.156698 -1.319103    -1.152348   -0.807864 -1.874492    -0.429449
# 39666  -1.607719 -0.378247    -1.627388   -1.286073 -1.935985    -0.429449
#
#        inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 39693       -0.730736               -0.518281               -5.471015
# 39671       -0.730736               -1.076572               -5.471015
# 39659       -0.730736               -1.076572               -5.471015
# 39660        1.458369               -1.076572               -5.471015
# 39666        1.458369                0.141517               -5.471015
#
#        open_acc  ...  purpose_home_improvement  purpose_house  \
# 39693 -0.881723  ...                 -0.248956      -0.064195
# 39671 -1.864116  ...                  4.016772      -0.064195
# 39659 -0.292287  ...                 -0.248956      -0.064195
# 39660 -1.471159  ...                 -0.248956      -0.064195
# 39666 -1.667638  ...                 -0.248956      -0.064195
#
#        purpose_major_purchase  purpose_medical  purpose_moving  purpose_other  \
# 39693               -0.140574        -0.098306       -0.077877      -0.224149
# 39671               -0.140574        -0.098306       -0.077877      -0.224149
# 39659               -0.140574        -0.098306       -0.077877      -0.224149
# 39660               -0.140574        -0.098306       -0.077877      -0.224149
# 39666               -0.140574        -0.098306       -0.077877      -0.224149
#
#        purpose_renewable_energy  purpose_small_business  purpose_vacation  \
# 39693                 -0.025334               -0.107535         -0.073038
# 39671                 -0.025334               -0.107535         -0.073038
# 39659                 -0.025334               -0.107535         -0.073038
# 39660                 -0.025334               -0.107535         -0.073038
# 39666                 -0.025334               -0.107535         -0.073038
#
#        loan_status
# 39693            0
# 39671            0
# 39659            0
# 39660            0
# 39666            0
#
# [5 rows x 90 columns]

# %%
x_train=train.iloc[:,0:89]
x_test=test.iloc[:,0:89]

# %%
y_train=train.iloc[:,-1]
y_test=test.iloc[:,-1]

# %% [markdown]
# # SMOTE - Synthetic Minority Oversampling Technique
# ### As the target variable is highly imbalanced SMOTE is to be applied

# %%
sns.countplot(y_train)

# %%
from imblearn.over_sampling import SMOTE

# %%
smt = SMOTE(random_state = 37) 
x_train_res, y_train_res = smt.fit_sample(x_train, y_train.ravel())

# %%
sns.countplot(y_train_res)

# %% [markdown]
# # Model Building

# %% [markdown]
# ### LOGISTIC REGRESSION WITHOUT SMOTE

# %%
# Libraries for Validation of models
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

logistic_model = LogisticRegression(solver='lbfgs').fit(x_train,y_train)
logistic_predict = logistic_model.predict(x_test)
logistic_confusion_matrix = confusion_matrix(y_test,logistic_predict)
logistic_confusion_matrix

# %% [markdown]
# ### LOGISTIC REGRESSION WITH SMOTE

# %%
# Libraries for Validation of models
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

logistic_model_1 = LogisticRegression(solver='lbfgs').fit(x_train_res,y_train_res)
logistic_predict_1 = logistic_model_1.predict(x_test)
logistic_confusion_matrix_1 = confusion_matrix(y_test,logistic_predict_1)
logistic_confusion_matrix_1

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(x_train,y_train)

# %%
predictions = dtree.predict(x_test)
dt_confusion_matrix = confusion_matrix(y_test,predictions)
dt_confusion_matrix

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators = 100, criterion='gini')
rf_model = rf_model.fit(x_train, y_train)
rf_model_predict = rf_model.predict(x_test)
rf_confusion_matrix = confusion_matrix(y_test,rf_model_predict)
rf_confusion_matrix

# %%
### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
NBC=GaussianNB()
NBC.fit(x_train, y_train)
NB_model_predict_test=NBC.predict(x_test)
NB_confusion_matrix = confusion_matrix(y_test,NB_model_predict_test)
NB_confusion_matrix

# %% [markdown]
# ## Evaluating Model
#
# * AUC - Area Under Curve
# * ROC - Reciever Operator Curve
# * Precision / Specificity
# * Recall / True Positive Rate / Sensitivity

# %%
# Report All Results into Dataframe - Creating Method Where Evaluation Parameters will generate from Confusion Matrix
report_comments, report_Accuracy, report_Precision, report_Recall , report_F1_Score = [],[],[],[],[]

def report_row(conf_mat,comment):
    # Append Comment into List
    report_comments.append(comment)

    # Calculating Accuracy and Append into List
    accuracy = (conf_mat[1][1] + conf_mat[0][0])/ (conf_mat[1][1] + conf_mat[0][0] + conf_mat[0][1] + conf_mat[1][0])
    report_Accuracy.append(accuracy)
    
    # Calculating Precision and Append into List
    precisoin = (conf_mat[0][0])/(conf_mat[0][1] + conf_mat[0][0])
    report_Precision.append(precisoin)
    
    # Calculating Recall and Append into List
    recall = (conf_mat[0][0])/(conf_mat[1][0] + conf_mat[0][0])
    report_Recall.append(recall)
    
    # Calculating F1-Score and Append into List
    f1score = 2 * precisoin * recall / (precisoin + recall) 
    report_F1_Score.append(f1score)
    
    
# Report All Results into Dataframe
def show_report():
    report_data = {'Comment': report_comments,
               'Accuracy': report_Accuracy,
               'Precision': report_Precision,
               'Recall': report_Recall ,
               'F1 Score': report_F1_Score
              }
    df_results = pd.DataFrame.from_dict(report_data)
    return(df_results)

# %%
# Pass all Generated Confusion Matrix for generate report
report_row(logistic_confusion_matrix, comment='Logistic Regression without SMOTE')
report_row(dt_confusion_matrix, comment='Decision Tree')
report_row(rf_confusion_matrix, comment='Random Forest')
report_row(NB_confusion_matrix, comment='Naive Bayes')

# %%
show_report()

# %%
Graphical_representation  =   {"Accuracy":[0.999568,0.997790,0.981350,0.968734,0.947769],
                               "Precision":[0.999848,0.998033,0.981366,0.968700,0.948500],
                               "Recall": [0.999720,0.999754,0.999960,0.999996,0.999163],
                               "F1 score": [0.999784,0.998893,0.990576,0.984099,0.973173]};
index               = ["Logistic Regression without SMOTE", "Logistic Regression with SMOTE", "Decision Tree", "Random Forest", "Naive Bayes"];
 
# Python dictionary into a pandas DataFrame
dataFrame       = pd.DataFrame(data = Graphical_representation);
dataFrame.index = index 
dataFrame.plot.barh(rot=15, title="Bar chart representation of Precision, Recall, Accuracy and F1 score.")
plt.legend(loc="lower center", ncol=2, bbox_to_anchor=(0.5,1.15))
plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ### The best model is Logistic regression without SMOTE(99.96% Accuracy)
